# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Amazon Sale Report.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df.shape
# Out:
# (128976, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %%
df.drop(['PendingS', 'New','index'], axis=1,inplace=True)

# %%
df.shape
# Out:
# (128976, 18)

# %%
df.isna().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Category                  0
# Size                      0
# Courier Status            0
# Qty                       0
# currency               7800
# Amount                 7800
# ship-city                35
# ship-state               35
# ship-postal-code         35
# ship-country             35
# B2B                       0
# fulfilled-by          89713
# dtype: int64

# %%
df['currency'].unique()
# Out:
# array(['INR', nan], dtype=object)

# %%
df['Amount'].unique()
# Out:
# array([ 647.62,  406.  ,  329.  , ...,  708.58, 1244.  ,  639.  ])

# %%
df['fulfilled-by'].unique()
# Out:
# array(['Easy Ship', nan], dtype=object)

# %%
df["currency"].fillna("INR", inplace=True)

# %%
df["Amount"].fillna(df["Amount"].mean(),inplace=True)

# %%
df["fulfilled-by"].fillna("Easy Ship", inplace=True)

# %%
df.isna().sum()
# Out:
# Order ID               0
# Date                   0
# Status                 0
# Fulfilment             0
# Sales Channel          0
# ship-service-level     0
# Category               0
# Size                   0
# Courier Status         0
# Qty                    0
# currency               0
# Amount                 0
# ship-city             35
# ship-state            35
# ship-postal-code      35
# ship-country          35
# B2B                    0
# fulfilled-by           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# fulfilled-by          0
# dtype: int64

# %%
x.shape
# Out:
# (121143, 18)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128941 entries, 0 to 128975
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128941 non-null  object
#  1   Date                128941 non-null  object
#  2   Status              128941 non-null  object
#  3   Fulfilment          128941 non-null  object
#  4   Sales Channel       128941 non-null  object
#  5   ship-service-level  128941 non-null  object
#  6   Category            128941 non-null  object
#  7   Size                128941 non-null  object
#  8   Courier Status      128941 non-null  object
#  9   Qty                 128941 non-null  int64
#  10  currency            128941 non-null  object
#  11  Amount              128941 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128941 entries, 0 to 128975
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128941 non-null  object
#  1   Date                128941 non-null  datetime64[ns]
#  2   Status              128941 non-null  object
#  3   Fulfilment          128941 non-null  object
#  4   Sales Channel       128941 non-null  object
#  5   ship-service-level  128941 non-null  object
#  6   Category            128941 non-null  object
#  7   Size                128941 non-null  object
#  8   Courier Status      128941 non-null  object
#  9   Qty                 128941 non-null  int64
#  10  currency            128941 non-null  object
#  11  Amount              128941 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
# ...

# %%
df["Order ID"]=df["Order ID"].str.replace('-','')

# %%
df["Order ID"]=df["Order ID"].astype('category')

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128941 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128941 non-null  category
#  1   Date                128941 non-null  datetime64[ns]
#  2   Status              128941 non-null  object
#  3   Fulfilment          128941 non-null  object
#  4   Sales Channel       128941 non-null  object
#  5   ship-service-level  128941 non-null  object
#  6   Category            128941 non-null  object
#  7   Size                128941 non-null  object
#  8   Courier Status      128941 non-null  object
#  9   Qty                 128941 non-null  int64
#  10  currency            128941 non-null  object
#  11  Amount              128941 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
# ...

# %%
#sabhi columns ki value check karna hai unique se

# %%
df.describe()
# Out:
#                  Qty         Amount  ship-postal-code
# count  128941.000000  128941.000000     128941.000000
# mean        0.904414     648.575985     463945.677744
# std         0.313356     272.561217     191458.488954
# min         0.000000       0.000000     110001.000000
# 25%         1.000000     459.000000     382421.000000
# 50%         1.000000     635.000000     500033.000000
# 75%         1.000000     771.000000     600024.000000
# max        15.000000    5584.000000     989898.000000

# %%
df.describe(include ='object') #string k liye
# Out:
#               Date   Status Fulfilment Sales Channel ship-service-level  \
# count       128941   128941     128941        128941             128941
# unique          91       13          2             2                  2
# top     05-03-2022  Shipped     Amazon     Amazon.in          Expedited
# freq          2085    77797      89691        128817              88608
#
#        Category    Size Courier Status currency  ship-city   ship-state  \
# count    128941  128941         128941   128941     128941       128941
# unique        9      11              4        1       8948           69
# top     T-shirt       M        Shipped      INR  BENGALURU  MAHARASHTRA
# freq      50280   22366         109458   128941      11208        22272
#
#        ship-country fulfilled-by
# count        128941       128941
# unique            1            1
# top              IN    Easy Ship
# freq         128941       128941

# %%
x['B2B']
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 128971    False
# 128972    False
# 128973    False
# 128974    False
# 128975    False
# Name: B2B, Length: 128941, dtype: bool

# %%
x.head()
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#   Sales Channel ship-service-level  Category Size Courier Status  Qty  \
# 0     Amazon.in           Standard   T-shirt    S     On the Way    0
# 1     Amazon.in           Standard     Shirt  3XL        Shipped    1
# 2     Amazon.in          Expedited     Shirt   XL        Shipped    1
# 3     Amazon.in           Standard   Blazzer    L     On the Way    0
# 4     Amazon.in          Expedited  Trousers  3XL        Shipped    1
#
#   currency  Amount    ship-city   ship-state  ship-postal-code ship-country  \
# ...

# %%
# plotting a bar chart for Size and it's count

ax = sns.countplot(x = 'Size',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [raw]
# # From above graphs we can see that the  medium size are mostly buyed by customers

# %%
# plotting a bar chart for Category vs total amount

sales_gen = df.groupby(['Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Category',y= 'Amount' ,data = sales_gen)
# Out:
# <Axes: xlabel='Category', ylabel='Amount'>

# %% [raw]
# #from above graph t-shirts are the mostly sell product

# %%
df.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
# total ship-city/amount from top 10 states

sales_state = df.groupby(['ship-city'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'ship-city',y= 'Amount')
# Out:
# <Axes: xlabel='ship-city', ylabel='Amount'>

# %% [raw]
# #customers are mostly from Bengluru city

# %%
sales_state = df.groupby(['ship-state'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'ship-state',y= 'Amount')
# Out:
# <Axes: xlabel='ship-state', ylabel='Amount'>

# %%
Maharastra state has most buyers

# %%
df.head()
# Out:
#             Order ID      Date                        Status Fulfilment  \
# 0  40580787845731545  04-30-22                     Cancelled   Merchant
# 1  17191981511101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  40406876767273146  04-30-22                       Shipped     Amazon
# 3  40396153778133951  04-30-22                     Cancelled   Merchant
# 4  40710697907240320  04-30-22                       Shipped     Amazon
#
#   Sales Channel ship-service-level  Category Size Courier Status  Qty  \
# 0     Amazon.in           Standard   T-shirt    S     On the Way    0
# 1     Amazon.in           Standard     Shirt  3XL        Shipped    1
# 2     Amazon.in          Expedited     Shirt   XL        Shipped    1
# 3     Amazon.in           Standard   Blazzer    L     On the Way    0
# 4     Amazon.in          Expedited  Trousers  3XL        Shipped    1
#
#   currency  Amount    ship-city   ship-state  ship-postal-code ship-country  \
# ...

# %%
item = df.groupby(['Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.relplot(kind='line',data=item,x='Category',y='Amount')
plt.xticks(rotation=45)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128941 entries, 0 to 128975
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128941 non-null  category
#  1   Date                128941 non-null  datetime64[ns]
#  2   Status              128941 non-null  object
#  3   Fulfilment          128941 non-null  object
#  4   Sales Channel       128941 non-null  object
#  5   ship-service-level  128941 non-null  object
#  6   Category            128941 non-null  object
#  7   Size                128941 non-null  object
#  8   Courier Status      128941 non-null  object
#  9   Qty                 128941 non-null  int64
#  10  currency            128941 non-null  object
#  11  Amount              128941 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
# ...

# %%
df['Month'] = df['Date'].dt.month

# %%
df.head()
# Out:
#             Order ID                          Date  \
# 0  40580787845731545 1970-01-01 00:00:00.000000004
# 1  17191981511101146 1970-01-01 00:00:00.000000004
# 2  40406876767273146 1970-01-01 00:00:00.000000004
# 3  40396153778133951 1970-01-01 00:00:00.000000004
# 4  40710697907240320 1970-01-01 00:00:00.000000004
#
#                          Status Fulfilment Sales Channel ship-service-level  \
# 0                     Cancelled   Merchant     Amazon.in           Standard
# 1  Shipped - Delivered to Buyer   Merchant     Amazon.in           Standard
# 2                       Shipped     Amazon     Amazon.in          Expedited
# 3                     Cancelled   Merchant     Amazon.in           Standard
# 4                       Shipped     Amazon     Amazon.in          Expedited
#
#    Category Size Courier Status  Qty currency  Amount    ship-city  \
# 0   T-shirt    S     On the Way    0      INR  647.62       MUMBAI
# ...

# %%
data = df['B2B'].value_counts()

# %%
colors = sns.color_palette('bright')[0:len(data)]

# %%
plt.pie(data, labels = ['retailer','B2B'], colors = colors, autopct='%.0f%%')
plt.show()

# %%
df['Sales Channel'].unique()
# Out:
# array(['Amazon.in', 'Non-Amazon'], dtype=object)

# %% [markdown]
# # now replacing amazon to 1 and non-amazon to 0

# %%
df["Sales Channel"]=df["Sales Channel"].str.replace('Amazon.in','1')
# Out:
# C:\Users\lnxhunt\AppData\Local\Temp\ipykernel_12356\3528979196.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Sales Channel"]=df["Sales Channel"].str.replace('Amazon.in','1')

# %%
df["Sales Channel"]=df["Sales Channel"].str.replace('Non-Amazon','0')

# %%
ax = sns.countplot(data = df, x = 'Category', hue = 'Sales Channel')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#most to the items are sell by amazon

# %%
df.head()
# Out:
#             Order ID                          Date  \
# 0  40580787845731545 1970-01-01 00:00:00.000000004
# 1  17191981511101146 1970-01-01 00:00:00.000000004
# 2  40406876767273146 1970-01-01 00:00:00.000000004
# 3  40396153778133951 1970-01-01 00:00:00.000000004
# 4  40710697907240320 1970-01-01 00:00:00.000000004
#
#                          Status Fulfilment Sales Channel ship-service-level  \
# 0                     Cancelled   Merchant             1           Standard
# 1  Shipped - Delivered to Buyer   Merchant             1           Standard
# 2                       Shipped     Amazon             1          Expedited
# 3                     Cancelled   Merchant             1           Standard
# 4                       Shipped     Amazon             1          Expedited
#
#    Category Size Courier Status  Qty currency  Amount    ship-city  \
# 0   T-shirt    S     On the Way    0      INR  647.62       MUMBAI
# ...

# %%
data = df['Sales Channel'].value_counts()

# %%
plt.pie(data, labels = ['amazon','non-amazon'], colors = colors, autopct='%.0f%%')
plt.show()

# %%
ax = sns.countplot(data = df, x = 'Size', hue = 'Category', dodge=True)   

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df['Fulfilment'].unique()
# Out:
# array(['Merchant', 'Amazon'], dtype=object)

# %% [markdown]
# # merchant= 1   and amazon=0

# %%
df["Fulfilment"]=df["Fulfilment"].str.replace('Merchant','1')

# %%
df["Fulfilment"]=df["Fulfilment"].str.replace('Amazon','0')

# %%
# Out:
# KeyboardInterrupt

# %%
ax = sns.countplot(x = 'Fulfilment',data = df)
new_labels = ['merchant', 'amazon']

ax.set_xticklabels(new_labels)
                   
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'Fulfilment', hue = 'Category', dodge=True)   

new_labels = ['merchant', 'amazon']

ax.set_xticklabels(new_labels)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df['Category'].unique()
# Out:
# array(['T-shirt', 'Shirt', 'Blazzer', 'Trousers', 'Perfume', 'Socks',
#        'Shoes', 'Wallet', 'Watch'], dtype=object)

# %%
df.groupby('Fulfilment')['Fulfilment'].agg("count")
# Out:
# Fulfilment
# 0    89691
# 1    39250
# Name: Fulfilment, dtype: int64

# %%
df.head()
# Out:
#               Order ID       Date                        Status Fulfilment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled          1
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer          1
# 2  404-0687676-7273146 2022-04-30                       Shipped          0
# 3  403-9615377-8133951 2022-04-30                     Cancelled          1
# 4  407-1069790-7240320 2022-04-30                       Shipped          0
#
#   Sales Channel ship-service-level  Category Size Courier Status  Qty  \
# 0             1           Standard   T-shirt    S     On the Way    0
# 1             1           Standard     Shirt  3XL        Shipped    1
# 2             1          Expedited     Shirt   XL        Shipped    1
# 3             1           Standard   Blazzer    L     On the Way    0
# 4             1          Expedited  Trousers  3XL        Shipped    1
#
#   currency  Amount    ship-city   ship-state  ship-postal-code ship-country  \
# ...

# %%
df['Status'].unique()
# Out:
# array(['Cancelled', 'Shipped - Delivered to Buyer', 'Shipped',
#        'Shipped - Returned to Seller', 'Shipped - Rejected by Buyer',
#        'Shipped - Lost in Transit', 'Shipped - Out for Delivery',
#        'Shipped - Returning to Seller', 'Shipped - Picked Up', 'Pending',
#        'Pending - Waiting for Pick Up', 'Shipped - Damaged', 'Shipping'],
#       dtype=object)

# %%
ax = sns.countplot(data = df, x = 'Category', hue = 'Status', dodge=True)   

for bars in ax.containers:
    ax.bar_label(bars)

# %% [raw]
# #from above graph t-shirts are mostly shiped

# %%
df['ship-service-level'].unique()

# %%
# Create the countplot
ax = sns.countplot(data=df, x='ship-city', hue='ship-service-level', dodge=True)

# Label the bars
for container in ax.containers:
    ax.bar_label(container)

# Show the plot
plt.show()
# Out:
# KeyboardInterrupt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get the top 5 'ship-service-level' values
top_values = df['ship-service-level'].value_counts().nlargest(5).index

# Filter the dataframe to include only the top 5 values
df_top5 = df[df['ship-service-level'].isin(top_values)]

# Create the countplot
ax = sns.countplot(data=df_top5, x='ship-service-level', hue='ship-city', dodge=True)

# Label the bars
for container in ax.containers:
    ax.bar_label(container)

# Show the plot
plt.show()

# %% [markdown]
# # Conclusion

# %% [raw]
# Medium-sized T-shirts have been bought more from Amazon.
# And the highest sales have been in the state of Maharashtra and in Bengaluru City
# And 45% of people prefer merchant to fill their needs and rest to the customers prefer Amazon.
# And T-shirts and shirts are the most selling product on Amazon.
# 40-45 % products are cancelled by customers.
